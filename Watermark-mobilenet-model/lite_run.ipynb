# %%
import tensorflow as tf
from PIL import Image
import PIL
import numpy as np
import os, ast
import cv2

interpreter = tf.lite.Interpreter(model_path="converted_watermark_mobilenetmodel.tflite")
interpreter.allocate_tensors()

input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

print("input_details", input_details)
print("output_details", output_details)

f = open("mobilenet_watermark_class_indices.txt", "r")
labels = f.read()
labels = ast.literal_eval(labels)

final_labels = {v: k for k, v in labels.items()}

def predict_image(imgname, from_test_dir):
    test_image = cv2.imread(imgname)
    test_image = cv2.cvtColor(test_image, cv2.COLOR_BGR2RGB)
    test_image = cv2.resize(test_image, (224, 224), cv2.INTER_AREA)
    test_image = np.expand_dims(test_image, axis=0)

    # Normalize from [-1, 1]
    test_image = (2.0 / 255.0) * test_image - 1.0
    test_image = test_image.astype(np.float32)

    interpreter.set_tensor(input_details[0]['index'], test_image)
    interpreter.invoke()
    result = interpreter.get_tensor(output_details[0]['index'])

    result_dict = dict()
    for key in list(final_labels.keys()):
        result_dict[final_labels[key]] = result[0][key]
    sorted_results = {k: v for k, v in sorted(result_dict.items(), key=lambda item: item[1], reverse=True)}

    if not from_test_dir:
        for label in sorted_results.keys():
            print("{}: {}%".format(label, sorted_results[label] * 100))

    final_result = dict()
    final_result[list(sorted_results.keys())[0]] = sorted_results[list(sorted_results.keys())[0]] * 100

    return final_result

def verify_test_dir():
    path = '..\\batch-test-images'
    folders = os.listdir(path)

    correct_preds = 0
    file_count = 0
    for fold in folders:
        files = os.listdir(path + '\\' + fold)
        for filename in files:
            final_string = fold
            prediction = predict_image(path + '\\{}\\'.format(fold) + filename, True)
            if list(prediction.keys())[0] == final_string:
                print("{}\{}: Correct Prediction".format(fold, filename), prediction)
                correct_preds += 1
            else:
                print("{}\{}: INCORRECT PREDICTION".format(fold, filename), prediction)
            file_count += 1

    print(correct_preds, file_count)
    acc=(correct_preds/file_count)*100
    print('accuracy:',acc)

print('=' * 50)
path='..\\test-images\\yesw.jpg'
dict_2=predict_image(path, False)
if dict_2.get('no_watermark') is not None:
    print(dict_2)
    a=cv2.imread(path)
    cv2.imshow('fake',a)
    cv2.waitKey(0)
    print("Fake")
    cv2.destroyAllWindows()
else:
    print(dict_2)
    a=cv2.imread(path)
    cv2.imshow('real',a)
    cv2.waitKey(0)
    print("Real")
    cv2.destroyAllWindows()
    
verify_test_dir()
# Out:
# input_details [{'name': 'serving_default_input_1:0', 'index': 0, 'shape': array([  1, 224, 224,   3]), 'shape_signature': array([ -1, 224, 224,   3]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]
# output_details [{'name': 'StatefulPartitionedCall:0', 'index': 177, 'shape': array([1, 2]), 'shape_signature': array([-1,  2]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]
# ==================================================
# yes_watermark: 95.20428776741028%
# no_watermark: 4.795708879828453%
# {'yes_watermark': 95.20428776741028}
# Real
# no_watermark\14973.jpg: Correct Prediction {'no_watermark': 99.9951958656311}
# no_watermark\1598521.jpg: Correct Prediction {'no_watermark': 99.96609687805176}
# no_watermark\1763665.jpg: Correct Prediction {'no_watermark': 99.92651343345642}
# no_watermark\2678095.jpg: Correct Prediction {'no_watermark': 99.32690262794495}
# no_watermark\3220384.jpg: Correct Prediction {'no_watermark': 99.84317421913147}
# no_watermark\3387772.jpg: Correct Prediction {'no_watermark': 99.83532428741455}
# no_watermark\3463555.jpg: Correct Prediction {'no_watermark': 99.96737241744995}
# no_watermark\4735591.jpg: Correct Prediction {'no_watermark': 97.34184741973877}
# no_watermark\5340844.jpg: Correct Prediction {'no_watermark': 99.90397095680237}
# no_watermark\5369858.jpg: Correct Prediction {'no_watermark': 99.770587682724}
# no_watermark\5909552.jpg: Correct Prediction {'no_watermark': 99.9550998210907}
# no_watermark\692512.jpg: Correct Prediction {'no_watermark': 99.98753070831299}
# no_watermark\8716808.jpg: Correct Prediction {'no_watermark': 99.95724558830261}
# no_watermark\9091867.jpg: Correct Prediction {'no_watermark': 99.89629983901978}
# no_watermark\high-contrast100newuv.jpg: Correct Prediction {'no_watermark': 50.51593780517578}
# no_watermark\high-contrast10old.jpg: Correct Prediction {'no_watermark': 73.1332540512085}
# no_watermark\high-contrast10oldf.jpg: Correct Prediction {'no_watermark': 72.54564166069031}
# no_watermark\high-contrast10oldUV.jpg: Correct Prediction {'no_watermark': 89.39291834831238}
# no_watermark\high-contrast20frontlight.jpg: INCORRECT PREDICTION {'yes_watermark': 94.20578479766846}
# no_watermark\high-contrast20frontlightwithoutcontrast.jpg: INCORRECT PREDICTION {'yes_watermark': 76.95671916007996}
# no_watermark\high-contrast20old1.jpg: INCORRECT PREDICTION {'yes_watermark': 95.30131816864014}
# no_watermark\high-contrast20oldbackfrontlight.jpg: Correct Prediction {'no_watermark': 85.91228723526001}
# no_watermark\high-contrasterror.jpg: Correct Prediction {'no_watermark': 94.3445086479187}
# yes_watermark\high-contrast100new.jpg: INCORRECT PREDICTION {'no_watermark': 61.43673062324524}
# yes_watermark\high-contrast100newback.jpg: Correct Prediction {'yes_watermark': 99.86011385917664}
# yes_watermark\high-contrast100newr.jpg: Correct Prediction {'yes_watermark': 99.12741780281067}
# yes_watermark\high-contrast10new.jpg: Correct Prediction {'yes_watermark': 94.63262557983398}
# yes_watermark\high-contrast10new1.jpg: INCORRECT PREDICTION {'no_watermark': 85.64949035644531}
# yes_watermark\high-contrast10new1r.jpg: Correct Prediction {'yes_watermark': 75.02611875534058}
# yes_watermark\high-contrast10new2.jpg: INCORRECT PREDICTION {'no_watermark': 95.26663422584534}
# yes_watermark\high-contrast10new3.jpg: Correct Prediction {'yes_watermark': 86.7327332496643}
# yes_watermark\high-contrast10newr.jpg: Correct Prediction {'yes_watermark': 97.06739783287048}
# yes_watermark\high-contrast200.jpg: Correct Prediction {'yes_watermark': 97.14111089706421}
# yes_watermark\high-contrast200back.jpg: Correct Prediction {'yes_watermark': 77.33011841773987}
# yes_watermark\high-contrast200backr.jpg: Correct Prediction {'yes_watermark': 97.69466519355774}
# yes_watermark\high-contrast20frontandback.jpg: INCORRECT PREDICTION {'no_watermark': 52.891331911087036}
# yes_watermark\high-contrast20frontandbackf.jpg: Correct Prediction {'yes_watermark': 75.25575160980225}
# yes_watermark\high-contrast20old.jpg: Correct Prediction {'yes_watermark': 98.10478687286377}
# yes_watermark\high-contrast20old1fb.jpg: Correct Prediction {'yes_watermark': 84.24981236457825}
# yes_watermark\high-contrast20oldtesseract.jpg: Correct Prediction {'yes_watermark': 62.564778327941895}
# yes_watermark\high-contrast20oldw.jpg: Correct Prediction {'yes_watermark': 95.20428776741028}
# yes_watermark\high-contrast500.jpg: Correct Prediction {'yes_watermark': 99.23794269561768}
# yes_watermark\high-contrast500back.jpg: Correct Prediction {'yes_watermark': 99.96953010559082}
# yes_watermark\high-contrast500backr.jpg: Correct Prediction {'yes_watermark': 99.94425177574158}
# yes_watermark\high-contrast500r.jpg: Correct Prediction {'yes_watermark': 99.95765089988708}
# yes_watermark\high-contrast50old.jpg: Correct Prediction {'yes_watermark': 98.45959544181824}
# yes_watermark\high-contrast50oldback.jpg: Correct Prediction {'yes_watermark': 98.14528226852417}
# yes_watermark\high-contrast50oldbackr.jpg: Correct Prediction {'yes_watermark': 99.93411898612976}
# yes_watermark\high-contrast50oldr.jpg: Correct Prediction {'yes_watermark': 99.9232292175293}
# yes_watermark\high-contrasttest.jpg: Correct Prediction {'yes_watermark': 99.29874539375305}
# yes_watermark\high-contrastwatermark1.jpg: Correct Prediction {'yes_watermark': 99.96486902236938}
# yes_watermark\high-contrastwatermark10.jpg: Correct Prediction {'yes_watermark': 99.5864987373352}
# yes_watermark\high-contrastwatermark11.jpg: Correct Prediction {'yes_watermark': 99.87764954566956}
# yes_watermark\high-contrastwatermark12.jpg: Correct Prediction {'yes_watermark': 99.58797693252563}
# yes_watermark\high-contrastwatermark13.jpg: Correct Prediction {'yes_watermark': 99.81531500816345}
# yes_watermark\high-contrastwatermark14.jpg: Correct Prediction {'yes_watermark': 99.92489218711853}
# yes_watermark\high-contrastwatermark15.jpg: Correct Prediction {'yes_watermark': 98.97700548171997}
# yes_watermark\high-contrastwatermark16.jpg: Correct Prediction {'yes_watermark': 99.90750551223755}
# yes_watermark\high-contrastwatermark17.jpg: Correct Prediction {'yes_watermark': 99.90485310554504}
# yes_watermark\high-contrastwatermark18.jpg: Correct Prediction {'yes_watermark': 99.71139430999756}
# yes_watermark\high-contrastwatermark19.jpg: Correct Prediction {'yes_watermark': 98.51362109184265}
# yes_watermark\high-contrastwatermark2.jpg: Correct Prediction {'yes_watermark': 99.26632642745972}
# yes_watermark\high-contrastwatermark20.jpg: Correct Prediction {'yes_watermark': 99.94451403617859}
# yes_watermark\high-contrastwatermark21.jpg: Correct Prediction {'yes_watermark': 99.97112154960632}
# yes_watermark\high-contrastwatermark22.jpg: Correct Prediction {'yes_watermark': 99.72915053367615}
# yes_watermark\high-contrastwatermark23.jpg: Correct Prediction {'yes_watermark': 99.9715268611908}
# yes_watermark\high-contrastwatermark24.jpg: Correct Prediction {'yes_watermark': 99.98037219047546}
# yes_watermark\high-contrastwatermark25.jpg: Correct Prediction {'yes_watermark': 94.81348395347595}
# yes_watermark\high-contrastwatermark26.jpg: Correct Prediction {'yes_watermark': 99.7575581073761}
# yes_watermark\high-contrastwatermark27.jpg: Correct Prediction {'yes_watermark': 99.36962723731995}
# yes_watermark\high-contrastwatermark28.jpg: Correct Prediction {'yes_watermark': 99.78504180908203}
# yes_watermark\high-contrastwatermark29.jpg: Correct Prediction {'yes_watermark': 99.85097050666809}
# yes_watermark\high-contrastwatermark3.jpg: Correct Prediction {'yes_watermark': 97.07922339439392}
# yes_watermark\high-contrastwatermark30.jpg: Correct Prediction {'yes_watermark': 99.8119056224823}
# yes_watermark\high-contrastwatermark4.jpg: Correct Prediction {'yes_watermark': 99.10597205162048}
# yes_watermark\high-contrastwatermark5.jpg: Correct Prediction {'yes_watermark': 99.55781102180481}
# yes_watermark\high-contrastwatermark6.jpg: Correct Prediction {'yes_watermark': 99.80399012565613}
# yes_watermark\high-contrastwatermark7.jpg: Correct Prediction {'yes_watermark': 98.25820922851562}
# yes_watermark\high-contrastwatermark8.jpg: Correct Prediction {'yes_watermark': 98.50738048553467}
# yes_watermark\high-contrastwatermark9.jpg: Correct Prediction {'yes_watermark': 67.11288094520569}
# 73 80
# accuracy: 91.25
